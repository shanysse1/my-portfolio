# %%
import matplotlib.pyplot as plt

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_participants = [487097, 551373, 270095, 1036842, 144024, 35060, 113313, 456362, 138935, 158151, 600097, 60976, 22501, 245564]
women_participants = [0, 412407, 223518, 0, 78781, 9609, 96904, 390482, 175594, 190768, 488592, 446583, 21054, 0]
ncaa_men = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]
ncaa_women = [0, 16614, 15632, 0, 5375, 2400, 12061, 27811, 12848, 8608, 30018, 17471, 1216, 0]

# Calculate percentages
men_percentages = [n / h * 100 for n, h in zip(ncaa_men, men_participants) if h != 0]
women_percentages = [n / h * 100 for n, h in zip(ncaa_women, women_participants) if h != 0]

# Plot
plt.figure(figsize=(10, 6))

plt.barh(sports[:len(men_percentages)], men_percentages, color='blue', label='Men')
plt.barh(sports[:len(women_percentages)], women_percentages, color='red', label='Women')

plt.xlabel('Percentage')
plt.ylabel('Sport')
plt.title('Percentage of High School Athletes Competing in NCAA by Sport and Gender')
plt.legend()

plt.gca().invert_yaxis()  # Invert y-axis to display highest participation at the top

# %%
import matplotlib.pyplot as plt

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_participants = [487097, 551373, 270095, 1036842, 144024, 35060, 113313, 456362, 138935, 158151, 600097, 60976, 22501, 245564]
women_participants = [0, 412407, 223518, 0, 78781, 9609, 96904, 390482, 175594, 190768, 488592, 446583, 21054, 0]
ncaa_men = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]
ncaa_women = [0, 16614, 15632, 0, 5375, 2400, 12061, 27811, 12848, 8608, 30018, 17471, 1216, 0]

# Calculate percentages
men_percentages = [n / sum(ncaa_men) * 100 for n in ncaa_men]
women_percentages = [n / sum(ncaa_women) * 100 for n in ncaa_women]

# Plot
plt.figure(figsize=(10, 6))

plt.pie(men_percentages, labels=sports, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of Men High School Athletes Competing in NCAA by Sport')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_participants = [487097, 551373, 270095, 1036842, 144024, 35060, 113313, 456362, 138935, 158151, 600097, 60976, 22501, 245564]
ncaa_men = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]

# Calculate participation rates
participation_rates = [n / h * 100 for n, h in zip(ncaa_men, men_participants)]

# Plot
plt.figure(figsize=(10, 6))
plt.hist(participation_rates, bins=10, edgecolor='black')
plt.xlabel('Participation Rate (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Participation Rates for Men\'s NCAA Sports')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_hs_participants = [487097, 551373, 270095, 1036842, 144024, 35060, 113313, 456362, 138935, 158151, 600097, 60976, 22501, 245564]
men_ncaa_participants = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]
women_hs_participants = [0, 412407, 223518, 0, 78781, 9609, 96904, 390482, 175594, 190768, 488592, 446583, 21054, 0]
women_ncaa_participants = [0, 16614, 15632, 0, 5375, 2400, 12061, 27811, 12848, 8608, 30018, 17471, 1216, 0]

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(men_hs_participants, men_ncaa_participants, color='blue', alpha=0.5, label='Men')
plt.scatter(women_hs_participants, women_ncaa_participants, color='red', alpha=0.5, label='Women')

# Add labels and title
plt.xlabel('Number of High School Participants')
plt.ylabel('Number of NCAA Participants')
plt.title('Comparison of High School vs. NCAA Participants by Gender')

# Add text labels for each point
for i, sport in enumerate(sports):
    plt.text(men_hs_participants[i], men_ncaa_participants[i], sport)
    plt.text(women_hs_participants[i], women_ncaa_participants[i], sport)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_ncaa_participants = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]
women_ncaa_participants = [0, 16614, 15632, 0, 5375, 2400, 12061, 27811, 12848, 8608, 30018, 17471, 1216, 0]

# Plot
plt.figure(figsize=(10, 6))

plt.stackplot(sports, men_ncaa_participants, women_ncaa_participants, labels=['Men', 'Women'], baseline='zero', alpha=0.5)

# Add labels and title
plt.xlabel('Sports')
plt.ylabel('Number of NCAA Participants')
plt.title('Distribution of NCAA Participants by Gender')

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
sports = ['Baseball', 'Basketball', 'Cross Country', 'Football', 'Golf', 'Ice Hockey', 'Lacrosse', 'Soccer', 'Swimming', 'Tennis', 'Track & Field', 'Volleyball', 'Water Polo', 'Wrestling']
men_hs_participants = [487097, 551373, 270095, 1036842, 144024, 35060, 113313, 456362, 138935, 158151, 600097, 60976, 22501, 245564]
men_ncaa_participants = [35460, 18816, 14270, 73557, 8609, 4229, 14310, 25072, 9697, 7838, 28698, 2163, 1047, 7239]
women_hs_participants = [0, 412407, 223518, 0, 78781, 9609, 96904, 390482, 175594, 190768, 488592, 446583, 21054, 0]
women_ncaa_participants = [0, 16614, 15632, 0, 5375, 2400, 12061, 27811, 12848, 8608, 30018, 17471, 1216, 0]

# Create figure and axis objects
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Bar plot for high school participants by gender
axs[0, 0].barh(sports, men_hs_participants, color='blue', label='Men')
axs[0, 0].barh(sports, women_hs_participants, color='red', label='Women')
axs[0, 0].set_xlabel('Number of High School Participants')
axs[0, 0].set_ylabel('Sport')
axs[0, 0].set_title('High School Participants by Sport and Gender')
axs[0, 0].legend()

# Scatter plot for comparison of high school vs. NCAA participants by gender
axs[0, 1].scatter(men_hs_participants, men_ncaa_participants, color='blue', alpha=0.5, label='Men')
axs[0, 1].scatter(women_hs_participants, women_ncaa_participants, color='red', alpha=0.5, label='Women')
axs[0, 1].set_xlabel('Number of High School Participants')
axs[0, 1].set_ylabel('Number of NCAA Participants')
axs[0, 1].set_title('Comparison of High School vs. NCAA Participants by Gender')
axs[0, 1].legend()

# Stack plot for distribution of NCAA participants by gender
axs[1, 0].stackplot(sports, men_ncaa_participants, women_ncaa_participants, labels=['Men', 'Women'], baseline='zero', alpha=0.5)
axs[1, 0].set_xlabel('Sports')
axs[1, 0].set_ylabel('Number of NCAA Participants')
axs[1, 0].set_title('Distribution of NCAA Participants by Gender')
axs[1, 0].tick_params(axis='x', rotation=90)
axs[1, 0].legend()

# Empty plot in bottom-right corner to maintain layout
axs[1, 1].axis('off')

plt.tight_layout()
plt.show()
